# %%
# n = 50
# persent = 1
# minus = 1
# 
# for i in range(1,n+1):
    # minus *= ((366-i)/365)
    # persent = 1-minus
    # print(f"{i}명일 때, {persent*100:.5f}%")
    
import hashlib
import os

# 주요 숫자 설정
BIT = 16
BYTE = BIT // 8  # 16비트는 2바이트입니다.
MAX = 50

def birthday():
    hash_pre = set()
    attempt = 0
    
    while True:
        attempt += 1
        msg = os.urandom(16)
        hash = hashlib.sha256(msg).digest()
        
        prefix = hash[:BYTE]
        
        if prefix in hash_pre:
            return attempt
        else:
            hash_pre.add(prefix)

crash_attempt = []
for i in range(MAX):
    attempt = birthday()
    crash_attempt.append(attempt)
    print(f"[{i+1}/{MAX}] 충돌까지 시도 횟수 : {attempt}")
    
average_attempt = sum(crash_attempt) / MAX
thr_attempt = 2**(BIT/2)

print(f"\n=== 총 {MAX}회 ===\n평균 충돌 발생 시도 : {average_attempt:.3f}\n이론상 횟수 : {thr_attempt:.0f}")
# Out:
# [1/50] 충돌까지 시도 횟수 : 483
# [2/50] 충돌까지 시도 횟수 : 322
# [3/50] 충돌까지 시도 횟수 : 527
# [4/50] 충돌까지 시도 횟수 : 250
# [5/50] 충돌까지 시도 횟수 : 196
# [6/50] 충돌까지 시도 횟수 : 146
# [7/50] 충돌까지 시도 횟수 : 223
# [8/50] 충돌까지 시도 횟수 : 539
# [9/50] 충돌까지 시도 횟수 : 293
# [10/50] 충돌까지 시도 횟수 : 301
# [11/50] 충돌까지 시도 횟수 : 593
# [12/50] 충돌까지 시도 횟수 : 394
# [13/50] 충돌까지 시도 횟수 : 244
# [14/50] 충돌까지 시도 횟수 : 198
# [15/50] 충돌까지 시도 횟수 : 454
# [16/50] 충돌까지 시도 횟수 : 51
# [17/50] 충돌까지 시도 횟수 : 65
# [18/50] 충돌까지 시도 횟수 : 52
# [19/50] 충돌까지 시도 횟수 : 196
# [20/50] 충돌까지 시도 횟수 : 58
# [21/50] 충돌까지 시도 횟수 : 161
# [22/50] 충돌까지 시도 횟수 : 276
# [23/50] 충돌까지 시도 횟수 : 232
# [24/50] 충돌까지 시도 횟수 : 253
# [25/50] 충돌까지 시도 횟수 : 132
# [26/50] 충돌까지 시도 횟수 : 430
# [27/50] 충돌까지 시도 횟수 : 413
# [28/50] 충돌까지 시도 횟수 : 533
# [29/50] 충돌까지 시도 횟수 : 468
# [30/50] 충돌까지 시도 횟수 : 61
# [31/50] 충돌까지 시도 횟수 : 124
# [32/50] 충돌까지 시도 횟수 : 378
# [33/50] 충돌까지 시도 횟수 : 216
# [34/50] 충돌까지 시도 횟수 : 153
# [35/50] 충돌까지 시도 횟수 : 140
# [36/50] 충돌까지 시도 횟수 : 375
# [37/50] 충돌까지 시도 횟수 : 423
# [38/50] 충돌까지 시도 횟수 : 266
# [39/50] 충돌까지 시도 횟수 : 199
# [40/50] 충돌까지 시도 횟수 : 121
# [41/50] 충돌까지 시도 횟수 : 239
# [42/50] 충돌까지 시도 횟수 : 172
# [43/50] 충돌까지 시도 횟수 : 269
# [44/50] 충돌까지 시도 횟수 : 399
# [45/50] 충돌까지 시도 횟수 : 216
# [46/50] 충돌까지 시도 횟수 : 724
# [47/50] 충돌까지 시도 횟수 : 354
# [48/50] 충돌까지 시도 횟수 : 58
# [49/50] 충돌까지 시도 횟수 : 539
# [50/50] 충돌까지 시도 횟수 : 379
#
# === 총 50회 ===
# 평균 충돌 발생 시도 : 285.760
# 이론상 횟수 : 256
